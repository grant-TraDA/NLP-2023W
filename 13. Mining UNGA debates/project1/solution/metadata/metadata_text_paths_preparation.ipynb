# %%
import pandas as pd
import numpy as np
import os

# %%
CORPORA_DIR_PATH = os.path.join(os.path.pardir, "corpora", "UN General Debate Corpus", "TXT")
CORPORA_DIR_PATH
# Out:
# '../corpora/UN General Debate Corpus/TXT'

# %%
def list_files(dir_path):
    files = []

    for root, dirs, filenames in os.walk(dir_path):
        for f in filenames:
            # add to list file names with their last directories (without dir_path)
            if f.endswith(".txt"):
                files.append(os.path.join(os.path.basename(root), f))
    return files


txt_files = list_files(CORPORA_DIR_PATH)

# %% [markdown]
# ### Adding paths to text files
#
# It is handled differently for speeches pre-2023 and for speeches from 2023.
#
# - For older speeches, we use the original metadata with ISO codes corresponding to the file names.
# - For newer speeches, we use ISO codes saved during the scraping process.

# %%
metadata = pd.read_csv("enhanced_metadata.csv")
metadata
# Out:
#        Year  Session ISO Code          Country     Name of Person Speaking  \
# 0      2022       77      BRA           Brazil              Jair Bolsonaro
# 1      2022       77      SEN          Senegal                  Macky Sail
# 2      2022       77      CHL            Chile          Gabriel Boric Font
# 3      2022       77      JOR           Jordan  Abdullah Ii Ibn Al Hussein
# 4      2022       77      COL         Colombia        Gustavo Petro Urrego
# ...     ...      ...      ...              ...                         ...
# 10676  2023       78      KAZ       Kazakhstan       Kassym-Jomart Tokayev
# 10677  2023       78      IRN             Iran        Seyyed Ebrahim Raisi
# 10678  2023       78      KGZ  Kyrgyz Republic              Sadyr Zhaparov
# 10679  2023       78      DEU          Germany                 Olaf Scholz
# 10680  2023       78      NGA          Nigeria           Bola Ahmed Tinubu
#
#              Post   Population   TFR  HDI           GDP  Unemployment Rate  \
# 0       President  215313498.0  1.65  NaN  1.901461e+12              9.461
# 1       President   17316449.0  4.36  NaN  2.537043e+10              3.434
# 2       President   19603733.0  1.74  NaN  2.814772e+11              7.784
# 3            King   11285869.0  3.02  NaN  4.311994e+10             17.874
# 4       President   51874024.0  1.75  NaN  3.557413e+11             10.726
# ...           ...          ...   ...  ...           ...                ...
# 10676   President   19606633.0  2.45  NaN           NaN              4.991
# 10677   President   89172767.0  1.52  NaN           NaN             11.098
# 10678   President    6735347.0  2.73  NaN           NaN              4.762
# 10679  Chancellor   83294633.0  1.51  NaN           NaN              3.258
# 10680   President  223804632.0  5.05  NaN           NaN              5.812
#
#        Gini       CO2  Democracy Index Region Name  \
# 0      51.3  2.245458             6.78    Americas
# 1      40.3  0.673835             5.72      Africa
# 2      47.7  4.304166             8.22    Americas
# 3      33.7  2.030201             3.17        Asia
# 4      50.8  1.922308             6.72    Americas
# ...     ...       ...              ...         ...
# 10676  26.9       NaN              NaN        Asia
# 10677  38.8       NaN              NaN        Asia
# 10678  26.8       NaN              NaN        Asia
# 10679  31.7       NaN              NaN      Europe
# 10680  43.0       NaN              NaN      Africa
#
#                        Sub-region Name
# 0      Latin America and the Caribbean
# 1                   Sub-Saharan Africa
# 2      Latin America and the Caribbean
# 3                         Western Asia
# 4      Latin America and the Caribbean
# ...                                ...
# 10676                     Central Asia
# 10677                    Southern Asia
# 10678                     Central Asia
# 10679                   Western Europe
# 10680               Sub-Saharan Africa
#
# [10681 rows x 16 columns]

# %%
original_base_metadata = pd.read_excel(os.path.join("metadata_sources", "base_metadata.xlsx"))
original_base_metadata
# Out:
#        Year  Session ISO Code                              Country  \
# 0      2022       77      BRA                              Brazil
# 1      2022       77      SEN                              Senegal
# 2      2022       77      CHL                                Chile
# 3      2022       77      JOR                               Jordan
# 4      2022       77      COL                             Colombia
# ...     ...      ...      ...                                  ...
# 10554  1946        1      USA             United States of America
# 10555  1946        1      IRN                                 Iran
# 10556  1946        1      URY                              Uruguay
# 10557  1946        1      LUX                           Luxembourg
# 10558  1946        1      UKR  Ukrainian Soviet Socialist Republic
#
#           Name of Person Speaking        Post Unnamed: 6
# 0                  Jair Bolsonaro  President         NaN
# 1                      Macky Sail  President         NaN
# 2              Gabriel Boric Font  President         NaN
# 3      Abdullah II ibn Al Hussein        King        NaN
# 4            Gustavo Petro Urrego  President         NaN
# ...                           ...         ...        ...
# 10554                  Mr. Austin         NaN        NaN
# 10555                 Mr. Entezam         NaN        NaN
# 10556                  Mr. Blanco         NaN        NaN
# 10557                    Mr. Bech         NaN        NaN
# 10558               Mr. Manuilsky         NaN        NaN
#
# [10559 rows x 7 columns]

# %%
new_speeches_metadata = pd.read_csv(os.path.join("metadata_sources", "attributes.csv"))
new_speeches_metadata
# Out:
#       pdf_name                     speaker_name  \
# 0    ni_en.pdf  Denis Ronaldo Moncada Colindres
# 1    in_en.pdf          Subrahmanyam Jaishankar
# 2    jm_en.pdf             Kamina Johnson Smith
# 3    bt_en.pdf                      Tandi Dorji
# 4    zm_en.pdf                   Stanley Kakubo
# ..         ...                              ...
# 117  kz_en.pdf            Kassym-Jomart Tokayev
# 118  ir_en.pdf             Seyyed Ebrahim Raisi
# 119  kg_en.pdf                   Sadyr Zhaparov
# 120  de_en.pdf                      Olaf Scholz
# 121  ng_en.pdf                Bola Ahmed Tinubu
#
#                                    speaker_position
# 0                      Minister for Foreign Affairs
# 1                     Minister for External Affairs
# 2    Minister for Foreign Affairs and Foreign Trade
# 3                      Minister for Foreign Affairs
# 4                      Minister for Foreign Affairs
# ..                                              ...
# 117                                       President
# 118                                       President
# 119                                       President
# 120                                      Chancellor
# 121                                       President
#
# [122 rows x 3 columns]

# %%
metadata_part1 = metadata.loc[metadata["Year"] < 2023]
metadata_part2 = metadata.loc[metadata["Year"] == 2023]

# %%
assert len(metadata_part1) == len(original_base_metadata)
assert np.all(metadata_part1["Year"] == original_base_metadata["Year"])
assert np.all(metadata_part1["Session"] == original_base_metadata["Session"])

# %%
assert len(metadata_part2) == len(new_speeches_metadata)
assert np.all(metadata_part2["Name of Person Speaking"].values == new_speeches_metadata["speaker_name"].str.title().values)

# %%
dir_path = (
    "Session "
    + original_base_metadata["Session"].astype(str).str.zfill(2)
    + " - "
    + original_base_metadata["Year"].astype(str)
)

file_path_original = (
    original_base_metadata["ISO Code"].astype(str)
    + "_"
    + original_base_metadata["Session"].astype(str).str.zfill(2)
    + "_"
    + original_base_metadata["Year"].astype(str)
    + ".txt"
)

file_path_improved = (
    metadata_part1["ISO Code"].astype(str)
    + "_"
    + metadata_part1["Session"].astype(str).str.zfill(2)
    + "_"
    + metadata_part1["Year"].astype(str)
    + ".txt"
)

metadata_part1["text_path"] = list(map(os.path.join, dir_path, file_path_original))
text_path_improved = pd.Series(map(os.path.join, dir_path, file_path_improved))
# Out:
# /var/folders/ry/g117_fjj5179gbtkl0ylryvr0000gn/T/ipykernel_8861/390610660.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_part1["text_path"] = list(map(os.path.join, dir_path, file_path_original))

# %%
metadata_part1.loc[~metadata_part1["text_path"].isin(txt_files), "text_path"]
# Out:
# 504       Session 75 - 2020/POR_75_2020.txt
# 1020      Session 72 - 2017/POR_72_2017.txt
# 1140      Session 72 - 2017/PKR_72_2017.txt
# 1186      Session 71 - 2016/ZFA_71_2016.txt
# 1191      Session 71 - 2016/POR_71_2016.txt
# 1395      Session 70 - 2015/CMR_70_2015.txt
# 1514      Session 70 - 2015/SGP_70_2015.txt
# 1545      Session 70 - 2015/UZB_70_2015.txt
# 1799       Session 68 - 2013/EC_68_2013.txt
# 2188       Session 66 - 2011/EC_66_2011.txt
# 4074      Session 56 - 2001/CHE_56_2001.txt
# 5510      Session 48 - 1993/CSK_48_1993.txt
# 6154      Session 44 - 1989/BTN_44_1989.txt
# 6249      Session 44 - 1989/PSE_44_1989.txt
# 6282     Session 44 - 1989/YDYE_44_1989.txt
# 6436     Session 43 - 1988/YDYE_43_1988.txt
# 6557      Session 42 - 1987/PSE_42_1987.txt
# 6589     Session 42 - 1987/YDYE_42_1987.txt
# 6594      Session 42 - 1987/nan_42_1987.txt
# 6739     Session 41 - 1986/YDYE_41_1986.txt
# 6833      Session 40 - 1985/NIC_40_1985.txt
# 6878     Session 40 - 1985/YDYE_40_1985.txt
# 7027     Session 39 - 1984/YDYE_39_1984.txt
# 7030      Session 39 - 1984/ZMB_39_1984.txt
# 7143      Session 38 - 1983/PSE_38_1983.txt
# 7177     Session 38 - 1983/YDYE_38_1983.txt
# 7322     Session 37 - 1982/YDYE_37_1982.txt
# 7343      Session 36 - 1981/BLZ_36_1981.txt
# 7381     Session 36 - 1981/GIN _36_1981.txt
# 7438      Session 36 - 1981/PSE_36_1981.txt
# 7469    Session 36 - 1981/YDYE _36_1981.txt
# 7618     Session 35 - 1980/YDYE_35_1980.txt
# 7673     Session 34 - 1979/GIN _34_1979.txt
# 7733      Session 34 - 1979/PSE_34_1979.txt
# 7764    Session 34 - 1979/YDYE _34_1979.txt
# 7905     Session 33 - 1978/YDYE_33_1978.txt
# 8015      Session 32 - 1977/PSE_32_1977.txt
# 8045      Session 32 - 1977/VNM_32_1977.txt
# 8047     Session 32 - 1977/YDYE_32_1977.txt
# 8181     Session 31 - 1976/YDYE_31_1976.txt
# 8307     Session 30 - 1975/YDYE_30_1975.txt
# 8436     Session 29 - 1974/YDYE_29_1974.txt
# 8448     Session 28 - 1973/BEN _28_1973.txt
# 8461      Session 28 - 1973/CIV_28_1973.txt
# 8484      Session 28 - 1973/GNQ_28_1973.txt
# 8557     Session 28 - 1973/YDYE_28_1973.txt
# 8682     Session 27 - 1972/YDYE_27_1972.txt
# 8726     Session 26 - 1971/GTM _26_1971.txt
# 8772      Session 26 - 1971/PRT_26_1971.txt
# 8799     Session 26 - 1971/YDYE_26_1971.txt
# 8927      Session 24 - 1969/DKN_24_1969.txt
# 8935     Session 24 - 1969/YDYE_24_1969.txt
# 9081     Session 23 - 1968/YDYE_23_1968.txt
# 9218     Session 21 - 1966/CAN _21_1966.txt
# 9675      Session 17 - 1962/POR_17_1962.txt
# 9709      Session 16 - 1961/PAR_16_1961.txt
# Name: text_path, dtype: object

# %%
metadata_part1.loc[
    (~metadata_part1["text_path"].isin(txt_files)) & (~text_path_improved.str.contains("not found")), "text_path"
] = text_path_improved[(~metadata_part1["text_path"].isin(txt_files)) & (~text_path_improved.str.contains("not found"))]

# %%
metadata_part1
# Out:
#        Year  Session ISO Code        Country     Name of Person Speaking  \
# 0      2022       77      BRA         Brazil              Jair Bolsonaro
# 1      2022       77      SEN        Senegal                  Macky Sail
# 2      2022       77      CHL          Chile          Gabriel Boric Font
# 3      2022       77      JOR         Jordan  Abdullah Ii Ibn Al Hussein
# 4      2022       77      COL       Colombia        Gustavo Petro Urrego
# ...     ...      ...      ...            ...                         ...
# 10554  1946        1      USA  United States                  Mr. Austin
# 10555  1946        1      IRN           Iran                 Mr. Entezam
# 10556  1946        1      URY        Uruguay                  Mr. Blanco
# 10557  1946        1      LUX     Luxembourg                    Mr. Bech
# 10558  1946        1      UKR        Ukraine               Mr. Manuilsky
#
#             Post   Population   TFR  HDI           GDP  Unemployment Rate  \
# 0      President  215313498.0  1.65  NaN  1.901461e+12              9.461
# 1      President   17316449.0  4.36  NaN  2.537043e+10              3.434
# 2      President   19603733.0  1.74  NaN  2.814772e+11              7.784
# 3           King   11285869.0  3.02  NaN  4.311994e+10             17.874
# 4      President   51874024.0  1.75  NaN  3.557413e+11             10.726
# ...          ...          ...   ...  ...           ...                ...
# 10554        NaN  140031458.0  2.83  NaN           NaN                NaN
# 10555        NaN   16071828.0  6.94  NaN           NaN                NaN
# 10556        NaN    2133431.0  2.69  NaN           NaN                NaN
# 10557        NaN     297340.0  2.33  NaN           NaN                NaN
# 10558        NaN   35840148.0  2.88  NaN           NaN                NaN
#
#        Gini        CO2  Democracy Index Region Name  \
# 0      51.3   2.245458             6.78    Americas
# 1      40.3   0.673835             5.72      Africa
# 2      47.7   4.304166             8.22    Americas
# 3      33.7   2.030201             3.17        Asia
# 4      50.8   1.922308             6.72    Americas
# ...     ...        ...              ...         ...
# 10554  38.9  15.904564              NaN    Americas
# 10555  46.7        NaN              NaN        Asia
# 10556  54.7        NaN              NaN    Americas
# 10557  28.9        NaN              NaN      Europe
# 10558  34.2        NaN              NaN      Europe
#
#                        Sub-region Name                          text_path
# 0      Latin America and the Caribbean  Session 77 - 2022/BRA_77_2022.txt
# 1                   Sub-Saharan Africa  Session 77 - 2022/SEN_77_2022.txt
# 2      Latin America and the Caribbean  Session 77 - 2022/CHL_77_2022.txt
# 3                         Western Asia  Session 77 - 2022/JOR_77_2022.txt
# 4      Latin America and the Caribbean  Session 77 - 2022/COL_77_2022.txt
# ...                                ...                                ...
# 10554                 Northern America  Session 01 - 1946/USA_01_1946.txt
# 10555                    Southern Asia  Session 01 - 1946/IRN_01_1946.txt
# 10556  Latin America and the Caribbean  Session 01 - 1946/URY_01_1946.txt
# 10557                   Western Europe  Session 01 - 1946/LUX_01_1946.txt
# 10558                   Eastern Europe  Session 01 - 1946/UKR_01_1946.txt
#
# [10559 rows x 17 columns]

# %%
dir_path = "Session " + metadata_part2["Session"].astype(str).str.zfill(2) + " - " + metadata_part2["Year"].astype(str)

file_path = (
    metadata_part2["ISO Code"].astype(str)
    + "_"
    + metadata_part2["Session"].astype(str).str.zfill(2)
    + "_"
    + metadata_part2["Year"].astype(str)
    + ".txt"
)

metadata_part2["text_path"] = list(map(os.path.join, dir_path, file_path))
# Out:
# /var/folders/ry/g117_fjj5179gbtkl0ylryvr0000gn/T/ipykernel_8861/1285491507.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata_part2["text_path"] = list(map(os.path.join, dir_path, file_path))

# %%
metadata = pd.concat([metadata_part1, metadata_part2], axis=0)

# %%
metadata = metadata.loc[metadata["text_path"].isin(txt_files)]

# %%
metadata = metadata.sort_values(
    by=["Year", "Session", "Country", "Name of Person Speaking"], ascending=[False, True, True, True]
)

# %%
metadata = metadata.reset_index(drop=True)

# %%
metadata.to_csv("enhanced_metadata.csv", index=False)
